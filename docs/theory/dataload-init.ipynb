# %%
from pathlib import Path

import rich

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
print = rich.print

# %%
basedir = Path("/home/jannik/storage/synchrotron-data/")
content = list(basedir.iterdir())
